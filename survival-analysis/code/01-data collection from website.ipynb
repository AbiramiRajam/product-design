# %% [markdown]
# # Using Predictive Analytics on Business Registration Trends to Prioritize Development Funds in San Francisco
#
# ## Problem Statement
#
# **How can predictive analytics using Survival Analysis Technique on business registration trends help prioritize neighborhoods for development funds in business-dense areas of San Francisco for Supervisor District 3?**
#
# Understanding where new businesses are emerging, and how business density evolves over time, allows City Funding Team to strategically allocate resources. Predictive models can uncover patterns in business registrations, enabling more informed, data-driven decisions about neighborhood-level investment.
#
# ---
#
# ## Data Collection Process
#
# ### Overview
#
# A Python script was developed to collect and store data on registered businesses in San Francisco. This data is retrieved from the [San Francisco Open Data API](https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis/about_data) and saved locally in a CSV format for further analysis.
#
# ### API Source
#
# - **Endpoint**: `https://data.sfgov.org/resource/g8m3-pdis.json`
# - **Limit per request**: 1,000 records (as per API specifications)
#
# ### Features of the Script
#
# #### 1. **CSV Loading**
# - The script attempts to load previously saved data from `sf_registered_business.csv`.
# - If the file does not exist, it initializes an empty DataFrame to begin data collection.
#
# #### 2. **Paginated Requests**
# - Records are fetched in batches of 1,000 using an adjustable offset.
# - Ensures complete data retrieval without overlap or duplication.
#
# #### 3. **Deduplication**
# - A `set` of `uniqueid` values is maintained to prevent duplicate records.
# - Only new, unseen records are added to the dataset.
#
# #### 4. **Data Storage**
# - New records are appended to the existing dataset.
# - The combined dataset is then saved back to `sf_registered_business.csv`.
#
# #### 5. **Error Handling**
# - The script handles common API issues like connection errors and JSON decoding problems.
# - Includes logging to capture any exceptions that occur during data retrieval.
#
# #### 6. **Execution Tracking**
# - Real-time progress updates are printed to the console.
# - Logs the number of new records fetched in each iteration.
# - Tracks and reports total execution time and the number of records processed.
#
# #### 7. **Rate Limiting**
# - Introduces a small delay between API requests to respect server load and avoid throttling.
#
# ---

# %%
import requests
import pandas as pd
import time

url = 'https://data.sfgov.org/resource/g8m3-pdis.json'  # Using JSON for structured data
csv_filename = '../data/sf_registered_business.csv'
limit = 1000
offset = 0
all_records = []
seen_ids = set()
total_fetched = 0

print("Fetching data in chunks and removing duplicates...")
start_time = time.time()

while True:
    fetch_start_time = time.time()
    params = {'$limit': limit, '$offset': offset}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        fetch_end_time = time.time()
        fetch_time = fetch_end_time - fetch_start_time
        num_records = len(data)
        total_fetched += num_records
        print(f"Fetched {num_records} records (offset: {offset}), Fetch time: {fetch_time:.2f} seconds")

        new_records = 0
        for record in data:
            unique_id = record.get('uniqueid')
            if unique_id and unique_id not in seen_ids:
                all_records.append(record)
                seen_ids.add(unique_id)
                new_records += 1

        print(f"Added {new_records} new unique records.")

        if num_records < limit:
            print("Finished fetching all data.")
            break

        offset += limit
        time.sleep(0.1)  

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data at offset {offset}: {e}")
        break
    except json.JSONDecodeError:
        print(f"Error decoding JSON response at offset {offset}.")
        break
    except Exception as e:
        print(f"An unexpected error occurred at offset {offset}: {e}")
        break

collect_start_time = time.time()
if all_records:
    df = pd.DataFrame(all_records)
    collect_end_time = time.time()
    collect_time = collect_end_time - collect_start_time
    print(f"\nData collected into DataFrame in {collect_time:.2f} seconds.")

    # Save the DataFrame to CSV
    save_start_time = time.time()
    df.to_csv(csv_filename, index=False)
    save_end_time = time.time()
    save_time = save_end_time - save_start_time
    print(f"Data saved to {csv_filename} in {save_time:.2f} seconds.")
    print(f"\nData saved successfully as {csv_filename}")  # Added success message

    print("\nFirst few rows of the saved DataFrame:")
    print(df.head())
    print("\nDataFrame information:")
    df.info()

else:
    print("No unique records were collected.")

total_time = time.time() - start_time
print(f"\nTotal execution time: {total_time:.2f} seconds.")
print(f"Total unique records collected: {len(seen_ids)}")
print(f"Total records fetched from API: {total_fetched}")
# Out:
# Fetching data in chunks and removing duplicates...
# Fetched 1000 records (offset: 0), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 1000), Fetch time: 1.12 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 2000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 3000), Fetch time: 1.19 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 4000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 5000), Fetch time: 1.25 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 6000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 7000), Fetch time: 1.19 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 8000), Fetch time: 0.96 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 9000), Fetch time: 1.17 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 10000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 11000), Fetch time: 1.60 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 12000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 13000), Fetch time: 1.35 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 14000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 15000), Fetch time: 1.27 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 16000), Fetch time: 0.83 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 17000), Fetch time: 75.83 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 18000), Fetch time: 0.86 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 19000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 20000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 21000), Fetch time: 0.83 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 22000), Fetch time: 0.82 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 23000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 24000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 25000), Fetch time: 0.83 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 26000), Fetch time: 0.83 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 27000), Fetch time: 0.82 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 28000), Fetch time: 0.84 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 29000), Fetch time: 0.84 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 30000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 31000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 32000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 33000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 34000), Fetch time: 0.92 seconds
# Added 986 new unique records.
# Fetched 1000 records (offset: 35000), Fetch time: 0.82 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 36000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 37000), Fetch time: 0.85 seconds
# Added 988 new unique records.
# Fetched 1000 records (offset: 38000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 39000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 40000), Fetch time: 0.93 seconds
# Added 988 new unique records.
# Fetched 1000 records (offset: 41000), Fetch time: 0.83 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 42000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 43000), Fetch time: 0.83 seconds
# Added 988 new unique records.
# Fetched 1000 records (offset: 44000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 45000), Fetch time: 0.86 seconds
# Added 987 new unique records.
# Fetched 1000 records (offset: 46000), Fetch time: 0.82 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 47000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 48000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 49000), Fetch time: 0.83 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 50000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 51000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 52000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 53000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 54000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 55000), Fetch time: 0.82 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 56000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 57000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 58000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 59000), Fetch time: 0.99 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 60000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 61000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 62000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 63000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 64000), Fetch time: 0.92 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 65000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 66000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 67000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 68000), Fetch time: 1.05 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 69000), Fetch time: 1.04 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 70000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 71000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 72000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 73000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 74000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 75000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 76000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 77000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 78000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 79000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 80000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 81000), Fetch time: 0.93 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 82000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 83000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 84000), Fetch time: 0.94 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 85000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 86000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 87000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 88000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 89000), Fetch time: 0.91 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 90000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 91000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 92000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 93000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 94000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 95000), Fetch time: 0.92 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 96000), Fetch time: 1.07 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 97000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 98000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 99000), Fetch time: 0.89 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 100000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 101000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 102000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 103000), Fetch time: 1.10 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 104000), Fetch time: 0.87 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 105000), Fetch time: 0.99 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 106000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 107000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 108000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 109000), Fetch time: 0.99 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 110000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 111000), Fetch time: 0.92 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 112000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 113000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 114000), Fetch time: 0.87 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 115000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 116000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 117000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 118000), Fetch time: 0.85 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 119000), Fetch time: 0.86 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 120000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 121000), Fetch time: 1.34 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 122000), Fetch time: 0.86 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 123000), Fetch time: 1.15 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 124000), Fetch time: 1.04 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 125000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 126000), Fetch time: 1.12 seconds
# Added 985 new unique records.
# Fetched 1000 records (offset: 127000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 128000), Fetch time: 1.11 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 129000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 130000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 131000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 132000), Fetch time: 1.08 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 133000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 134000), Fetch time: 0.92 seconds
# Added 984 new unique records.
# Fetched 1000 records (offset: 135000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 136000), Fetch time: 0.86 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 137000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 138000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 139000), Fetch time: 0.95 seconds
# Added 984 new unique records.
# Fetched 1000 records (offset: 140000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 141000), Fetch time: 0.87 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 142000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 143000), Fetch time: 1.02 seconds
# Added 984 new unique records.
# Fetched 1000 records (offset: 144000), Fetch time: 1.23 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 145000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 146000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 147000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 148000), Fetch time: 0.97 seconds
# Added 984 new unique records.
# Fetched 1000 records (offset: 149000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 150000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 151000), Fetch time: 1.13 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 152000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 153000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 154000), Fetch time: 1.01 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 155000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 156000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 157000), Fetch time: 0.94 seconds
# Added 966 new unique records.
# Fetched 1000 records (offset: 158000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 159000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 160000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 161000), Fetch time: 0.88 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 162000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 163000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 164000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 165000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 166000), Fetch time: 0.97 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 167000), Fetch time: 0.90 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 168000), Fetch time: 1.04 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 169000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 170000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 171000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 172000), Fetch time: 0.99 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 173000), Fetch time: 1.02 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 174000), Fetch time: 1.12 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 175000), Fetch time: 0.89 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 176000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 177000), Fetch time: 1.01 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 178000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 179000), Fetch time: 1.03 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 180000), Fetch time: 1.09 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 181000), Fetch time: 0.97 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 182000), Fetch time: 1.01 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 183000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 184000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 185000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 186000), Fetch time: 0.96 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 187000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 188000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 189000), Fetch time: 1.02 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 190000), Fetch time: 1.28 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 191000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 192000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 193000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 194000), Fetch time: 0.92 seconds
# Added 957 new unique records.
# Fetched 1000 records (offset: 195000), Fetch time: 1.00 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 196000), Fetch time: 1.02 seconds
# Added 960 new unique records.
# Fetched 1000 records (offset: 197000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 198000), Fetch time: 1.00 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 199000), Fetch time: 1.05 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 200000), Fetch time: 0.95 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 201000), Fetch time: 0.95 seconds
# Added 967 new unique records.
# Fetched 1000 records (offset: 202000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 203000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 204000), Fetch time: 0.90 seconds
# Added 994 new unique records.
# Fetched 1000 records (offset: 205000), Fetch time: 1.07 seconds
# Added 973 new unique records.
# Fetched 1000 records (offset: 206000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 207000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 208000), Fetch time: 0.96 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 209000), Fetch time: 0.95 seconds
# Added 976 new unique records.
# Fetched 1000 records (offset: 210000), Fetch time: 1.03 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 211000), Fetch time: 0.92 seconds
# Added 983 new unique records.
# Fetched 1000 records (offset: 212000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 213000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 214000), Fetch time: 1.04 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 215000), Fetch time: 0.91 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 216000), Fetch time: 1.03 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 217000), Fetch time: 1.06 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 218000), Fetch time: 0.93 seconds
# Added 994 new unique records.
# Fetched 1000 records (offset: 219000), Fetch time: 0.95 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 220000), Fetch time: 1.05 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 221000), Fetch time: 1.14 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 222000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 223000), Fetch time: 1.01 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 224000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 225000), Fetch time: 0.95 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 226000), Fetch time: 0.99 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 227000), Fetch time: 1.23 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 228000), Fetch time: 0.93 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 229000), Fetch time: 1.04 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 230000), Fetch time: 0.99 seconds
# Added 996 new unique records.
# Fetched 1000 records (offset: 231000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 232000), Fetch time: 0.92 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 233000), Fetch time: 1.12 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 234000), Fetch time: 0.92 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 235000), Fetch time: 0.95 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 236000), Fetch time: 0.98 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 237000), Fetch time: 0.92 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 238000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 239000), Fetch time: 0.91 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 240000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 241000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 242000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 243000), Fetch time: 1.15 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 244000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 245000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 246000), Fetch time: 0.98 seconds
# Added 995 new unique records.
# Fetched 1000 records (offset: 247000), Fetch time: 0.99 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 248000), Fetch time: 0.96 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 249000), Fetch time: 0.96 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 250000), Fetch time: 1.08 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 251000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 252000), Fetch time: 0.99 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 253000), Fetch time: 1.01 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 254000), Fetch time: 0.97 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 255000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 256000), Fetch time: 1.05 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 257000), Fetch time: 1.08 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 258000), Fetch time: 1.05 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 259000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 260000), Fetch time: 1.24 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 261000), Fetch time: 1.03 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 262000), Fetch time: 0.94 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 263000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 264000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 265000), Fetch time: 0.99 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 266000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 267000), Fetch time: 1.10 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 268000), Fetch time: 1.01 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 269000), Fetch time: 0.96 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 270000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 271000), Fetch time: 0.94 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 272000), Fetch time: 1.05 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 273000), Fetch time: 1.08 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 274000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 275000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 276000), Fetch time: 0.97 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 277000), Fetch time: 1.10 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 278000), Fetch time: 1.57 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 279000), Fetch time: 1.16 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 280000), Fetch time: 1.13 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 281000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 282000), Fetch time: 1.01 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 283000), Fetch time: 1.00 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 284000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 285000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 286000), Fetch time: 1.06 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 287000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 288000), Fetch time: 0.99 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 289000), Fetch time: 1.03 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 290000), Fetch time: 1.04 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 291000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 292000), Fetch time: 1.06 seconds
# Added 993 new unique records.
# Fetched 1000 records (offset: 293000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 294000), Fetch time: 0.91 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 295000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 296000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 297000), Fetch time: 1.06 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 298000), Fetch time: 1.02 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 299000), Fetch time: 1.13 seconds
# Added 994 new unique records.
# Fetched 1000 records (offset: 300000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 301000), Fetch time: 1.29 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 302000), Fetch time: 0.95 seconds
# Added 990 new unique records.
# Fetched 1000 records (offset: 303000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 304000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 305000), Fetch time: 0.95 seconds
# Added 977 new unique records.
# Fetched 1000 records (offset: 306000), Fetch time: 1.00 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 307000), Fetch time: 1.07 seconds
# Added 973 new unique records.
# Fetched 1000 records (offset: 308000), Fetch time: 1.07 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 309000), Fetch time: 1.01 seconds
# Added 981 new unique records.
# Fetched 1000 records (offset: 310000), Fetch time: 1.03 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 311000), Fetch time: 1.06 seconds
# Added 997 new unique records.
# Fetched 1000 records (offset: 312000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 313000), Fetch time: 1.03 seconds
# Added 987 new unique records.
# Fetched 1000 records (offset: 314000), Fetch time: 1.01 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 315000), Fetch time: 0.95 seconds
# Added 984 new unique records.
# Fetched 1000 records (offset: 316000), Fetch time: 1.04 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 317000), Fetch time: 0.97 seconds
# Added 994 new unique records.
# Fetched 1000 records (offset: 318000), Fetch time: 1.04 seconds
# Added 992 new unique records.
# Fetched 1000 records (offset: 319000), Fetch time: 1.13 seconds
# Added 999 new unique records.
# Fetched 1000 records (offset: 320000), Fetch time: 1.12 seconds
# Added 998 new unique records.
# Fetched 1000 records (offset: 321000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 322000), Fetch time: 1.23 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 323000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 324000), Fetch time: 1.06 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 325000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 326000), Fetch time: 1.02 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 327000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 328000), Fetch time: 0.93 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 329000), Fetch time: 1.07 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 330000), Fetch time: 0.96 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 331000), Fetch time: 1.19 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 332000), Fetch time: 1.06 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 333000), Fetch time: 1.08 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 334000), Fetch time: 1.12 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 335000), Fetch time: 0.95 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 336000), Fetch time: 1.10 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 337000), Fetch time: 0.98 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 338000), Fetch time: 1.03 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 339000), Fetch time: 1.25 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 340000), Fetch time: 1.12 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 341000), Fetch time: 1.00 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 342000), Fetch time: 1.15 seconds
# Added 1000 new unique records.
# Fetched 1000 records (offset: 343000), Fetch time: 2.14 seconds
# Added 1000 new unique records.
# Fetched 15 records (offset: 344000), Fetch time: 0.74 seconds
# Added 15 new unique records.
# Finished fetching all data.
#
# Data collected into DataFrame in 0.89 seconds.
# Data saved to ../data/sf_registered_business.csv in 2.04 seconds.
#
# Data saved successfully as ../data/sf_registered_business.csv
#
# First few rows of the saved DataFrame:
#                  uniqueid           ttxid certificate_number  \
# 0  1273263-03-211-1122847  1273263-03-211            1122847
# 1  0443734-01-999-0443734  0443734-01-999            0443734
# 2  0324890-02-999-0324890  0324890-02-999            0324890
# 3  0312666-01-999-0312666  0312666-01-999            0312666
# 4  1022875-03-151-0466955  1022875-03-151            0466955
#
#        ownership_name           dba_name full_business_address         city  \
# 0      Miguel Salcido     Miguel Salcido    290 Nagareda Dr #5       Gilroy
# 1       Zhen Canguang      Canguang Zhen         142 Peoria St    Daly City
# 2     Alfaro Miguel A           Alfaro's         2239 66th Ave   Sacramento
# 3   Brookins George G  Brookins Electric           22 Braun Ct    Sausalito
# 4  Range Networks Inc     Range Networks       2040 Martin Ave  Santa Clara
#
#   state business_zip           dba_start_date  ...  \
# 0    CA        95020  2021-03-25T00:00:00.000  ...
# 1    CA        94014  2009-11-04T00:00:00.000  ...
# 2    CA        95822  1999-01-01T00:00:00.000  ...
# 3    CA        94965  1998-01-10T00:00:00.000  ...
# 4    CA        95050  2011-06-01T00:00:00.000  ...
#
#   :@computed_region_ajp5_b2md :@computed_region_jwn9_ihcz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_qgnn_b9vv naic_code naic_code_description  \
# 0                         NaN       NaN                   NaN
# 1                         NaN       NaN                   NaN
# 2                         NaN       NaN                   NaN
# 3                         NaN       NaN                   NaN
# 4                         NaN       NaN                   NaN
#
#   naics_code_descriptions_list  lic  lic_code_description  \
# 0                          NaN  NaN                   NaN
# 1                          NaN  NaN                   NaN
# 2                          NaN  NaN                   NaN
# 3                          NaN  NaN                   NaN
# 4                          NaN  NaN                   NaN
#
#   lic_code_descriptions_list business_corridor
# 0                        NaN               NaN
# 1                        NaN               NaN
# 2                        NaN               NaN
# 3                        NaN               NaN
# 4                        NaN               NaN
#
# [5 rows x 37 columns]
#
# DataFrame information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342682 entries, 0 to 342681
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   uniqueid                           342682 non-null  object
#  1   ttxid                              342682 non-null  object
#  2   certificate_number                 342682 non-null  object
#  3   ownership_name                     342682 non-null  object
#  4   dba_name                           342682 non-null  object
#  5   full_business_address              342677 non-null  object
#  6   city                               342482 non-null  object
#  7   state                              342029 non-null  object
#  8   business_zip                       341985 non-null  object
#  9   dba_start_date                     342682 non-null  object
#  10  location_start_date                342682 non-null  object
#  11  location_end_date                  218192 non-null  object
#  12  mailing_address_1                  160898 non-null  object
#  13  mail_city                          160890 non-null  object
#  14  mail_zipcode                       160873 non-null  object
#  15  mail_state                         160838 non-null  object
#  16  parking_tax                        342682 non-null  bool
#  17  transient_occupancy_tax            342682 non-null  bool
#  18  location                           341364 non-null  object
#  19  data_as_of                         342682 non-null  object
#  20  data_loaded_at                     342682 non-null  object
#  21  dba_end_date                       181770 non-null  object
#  22  administratively_closed            40889 non-null   object
#  23  supervisor_district                277127 non-null  object
#  24  neighborhoods_analysis_boundaries  277108 non-null  object
#  25  :@computed_region_6qbp_sg9q        277114 non-null  object
#  26  :@computed_region_26cr_cadq        277116 non-null  object
#  27  :@computed_region_ajp5_b2md        277108 non-null  object
#  28  :@computed_region_jwn9_ihcz        277114 non-null  object
#  29  :@computed_region_qgnn_b9vv        275696 non-null  object
#  30  naic_code                          184286 non-null  object
#  31  naic_code_description              184286 non-null  object
#  32  naics_code_descriptions_list       184286 non-null  object
#  33  lic                                14258 non-null   object
#  34  lic_code_description               14258 non-null   object
#  35  lic_code_descriptions_list         14258 non-null   object
#  36  business_corridor                  31253 non-null   object
# dtypes: bool(2), object(35)
# memory usage: 92.2+ MB
#
# Total execution time: 452.90 seconds.
# Total unique records collected: 342682
# Total records fetched from API: 344015
